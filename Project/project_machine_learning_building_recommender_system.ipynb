# %% [markdown]
# There are two basic types of recommendation systems:
#
# 1. Simple Recommendation System
# 2. Content-Based Recommendation System
#
# The Simple Recommendation System, as the name suggests, is a system that relies only on ranking as the basis for its recommendations. It is commonly used in “Top 5 movies” lists, where the order is determined by factors such as the most votes, highest ratings, best sales, or other similar metrics.
#
# In this case, we will use a combination of average rating and number of votes to create a new metric derived from these existing metrics, and then we will sort this metric from highest to lowest.

# %%
# Import library

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
url_1 = 'https://storage.googleapis.com/dqlab-dataset/title.basics.tsv'
url_2 = 'https://storage.googleapis.com/dqlab-dataset/title.ratings.tsv'

df_basic = pd.read_csv (url_1, sep = '\t')
df_rating = pd.read_csv (url_2, sep = '\t')

df_basic.head(10)
# Out:
#       tconst  titleType                                      primaryTitle  \
# 0  tt0221078      short                         Circle Dance, Ute Indians
# 1  tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2  tt7157720  tvEpisode                                     Episode #3.41
# 3  tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4  tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
# 5  tt0043745      short                                         Lion Down
# 6  tt1009561  tvEpisode                             Saikyô no kikku chîmu
# 7  tt5038380    tvMovie                                 (Working) Holiday
# 8  tt0167491      video                                 Wicked Covergirls
# 9  tt7201644  tvEpisode                                     Episode #1.33
#
#                                       originalTitle  isAdult startYear  \
# 0                         Circle Dance, Ute Indians        0      1898
# 1  ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                     Episode #3.41        0      2016
# 3                         Episode dated 16 May 1987        0      1987
# 4                  Frances Bavier: Aunt Bee Retires        0      1973
# 5                                         Lion Down        0      1951
# 6                             Saikyô no kikku chîmu        0      2006
# 7                                 (Working) Holiday        0      2015
# 8                                 Wicked Covergirls        1      1998
# 9                                     Episode #1.33        0      2006
#
#   endYear runtimeMinutes                   genres
# 0      \N             \N        Documentary,Short
# 1      \N             \N             Comedy,Drama
# 2      \N             29         Comedy,Game-Show
# 3      \N             \N                     News
# 4      \N             \N              Documentary
# 5      \N              7  Animation,Comedy,Family
# 6      \N             23   Animation,Comedy,Drama
# 7      \N             23                   Comedy
# 8      \N             85                    Adult
# 9      \N             45            Drama,Romance

# %%
df_rating.head(10)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1608
# 1  tt0000002            6.0       197
# 2  tt0000003            6.5      1285
# 3  tt0000004            6.1       121
# 4  tt0000005            6.1      2050
# 5  tt0000006            5.1       111
# 6  tt0000007            5.4       639
# 7  tt0000008            5.4      1760
# 8  tt0000009            5.8       136
# 9  tt0000010            6.9      5778

# %%
df_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9025 entries, 0 to 9024
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          9025 non-null   object
#  1   titleType       9025 non-null   object
#  2   primaryTitle    9011 non-null   object
#  3   originalTitle   9011 non-null   object
#  4   isAdult         9025 non-null   int64
#  5   startYear       9025 non-null   object
#  6   endYear         9025 non-null   object
#  7   runtimeMinutes  9025 non-null   object
#  8   genres          9014 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 634.7+ KB

# %%
df_basic.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      14
# originalTitle     14
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            11
# dtype: int64

# %%
df_basic.loc[(df_basic['primaryTitle'].isnull()) | (df_basic['originalTitle'].isnull())]
# Out:
#           tconst  titleType primaryTitle originalTitle  isAdult startYear  \
# 9000  tt10790040  tvEpisode          NaN           NaN        0      2019
# 9001  tt10891902  tvEpisode          NaN           NaN        0      2020
# 9002  tt11737860  tvEpisode          NaN           NaN        0      2020
# 9003  tt11737862  tvEpisode          NaN           NaN        0      2020
# 9004  tt11737866  tvEpisode          NaN           NaN        0      2020
# 9005  tt11737872  tvEpisode          NaN           NaN        0      2020
# 9006  tt11737874  tvEpisode          NaN           NaN        0      2020
# 9007   tt1971246  tvEpisode          NaN           NaN        0      2011
# 9008   tt2067043  tvEpisode          NaN           NaN        0      1965
# 9009   tt4404732  tvEpisode          NaN           NaN        0      2015
# 9010   tt5773048  tvEpisode          NaN           NaN        0      2015
# 9011   tt8473688  tvEpisode          NaN           NaN        0      1987
# 9012   tt8541336  tvEpisode          NaN           NaN        0      2018
# 9013   tt9824302  tvEpisode          NaN           NaN        0      2016
#
#      endYear runtimeMinutes                genres
# 9000      \N             \N                    \N
# 9001      \N             \N                 Crime
# 9002      \N             \N  Comedy,Drama,Romance
# 9003      \N             \N  Comedy,Drama,Romance
# 9004      \N             \N  Comedy,Drama,Romance
# 9005      \N             \N                    \N
# 9006      \N             \N  Comedy,Drama,Romance
# 9007      \N             \N             Biography
# 9008      \N             \N                 Music
# 9009      \N             \N                Comedy
# 9010      \N             \N             Talk-Show
# 9011      \N             \N                 Drama
# 9012      \N             \N    Reality-TV,Romance
# 9013      \N             \N           Documentary

# %%
df_basic = df_basic.loc[(df_basic['primaryTitle'].notnull()) & (df_basic['originalTitle'].notnull())]

# %%
len(df_basic)
# Out:
# 9011

# %%
df_basic.loc[df_basic['genres'].isnull()]
# Out:
#           tconst  titleType  \
# 9014  tt10233364  tvEpisode
# 9015  tt10925142  tvEpisode
# 9016  tt10970874  tvEpisode
# 9017  tt11670006  tvEpisode
# 9018  tt11868642  tvEpisode
# 9019   tt2347742  tvEpisode
# 9020   tt3984412  tvEpisode
# 9021   tt8740950  tvEpisode
# 9022   tt9822816  tvEpisode
# 9023   tt9900062  tvEpisode
# 9024   tt9909210  tvEpisode
#
#                                            primaryTitle originalTitle  \
# 9014  Rolling in the Deep Dish\tRolling in the Deep ...             0
# 9015  The IMDb Show on Location: Star Wars Galaxy's ...             0
# 9016  Die Bauhaus-Stadt Tel Aviv - Vorbild für die M...             0
# 9017  ...ein angenehmer Unbequemer...\t...ein angene...             0
# 9018  GGN Heavyweight Championship Lungs With Mike T...             0
# 9019  No sufras por la alergia esta primavera\tNo su...             0
# 9020  I'm Not Going to Come Last, I'm Just Going to ...             0
# 9021  Weight Loss Resolution Restart - Ins & Outs of...             0
# 9022  Zwischen Vertuschung und Aufklärung - Missbrau...             0
# 9023  The Direction of Yuu's Love: Hings Aren't Goin...             0
# 9024  Politik und/oder Moral - Wie weit geht das Ver...             0
#
#       isAdult startYear endYear          runtimeMinutes genres
# 9014     2019        \N      \N              Reality-TV    NaN
# 9015     2019        \N      \N               Talk-Show    NaN
# 9016     2019        \N      \N                      \N    NaN
# 9017     1981        \N      \N             Documentary    NaN
# 9018     2020        \N      \N               Talk-Show    NaN
# 9019     2004        \N      \N                      \N    NaN
# 9020     2014        \N      \N              Reality-TV    NaN
# 9021     2015        \N      \N              Reality-TV    NaN
# 9022     2019        \N      \N                      \N    NaN
# 9023     1994        \N      \N  Animation,Comedy,Drama    NaN
# 9024     2005        \N      \N                      \N    NaN

# %%
df_basic.loc[df_basic['genres'].notnull()]
# Out:
#           tconst  titleType                                      primaryTitle  \
# 0      tt0221078      short                         Circle Dance, Ute Indians
# 1      tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2      tt7157720  tvEpisode                                     Episode #3.41
# 3      tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4      tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
# ...          ...        ...                                               ...
# 8995   tt1357878  tvEpisode                                            Poison
# 8996   tt2252371  tvEpisode                    Episode dated 20 February 2012
# 8997   tt6934076  tvEpisode                                     Episode #1.59
# 8998  tt11988828  tvEpisode                                    Episode #1.263
# 8999  tt11285464      short                                        Hoodie XXX
#
#                                          originalTitle  isAdult startYear  \
# 0                            Circle Dance, Ute Indians        0      1898
# 1     ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                        Episode #3.41        0      2016
# 3                            Episode dated 16 May 1987        0      1987
# 4                     Frances Bavier: Aunt Bee Retires        0      1973
# ...                                                ...      ...       ...
# 8995                                            Poison        0      2004
# 8996                    Episode dated 20 February 2012        0      2012
# 8997                                     Episode #1.59        0      2012
# 8998                                    Episode #1.263        0        \N
# 8999                                        Hoodie XXX        0      2019
#
#      endYear runtimeMinutes             genres
# 0         \N             \N  Documentary,Short
# 1         \N             \N       Comedy,Drama
# 2         \N             29   Comedy,Game-Show
# 3         \N             \N               News
# 4         \N             \N        Documentary
# ...      ...            ...                ...
# 8995      \N             \N        Documentary
# 8996      \N             \N          Talk-Show
# 8997      \N             \N          Talk-Show
# 8998      \N             \N              Drama
# 8999      \N             \N       Horror,Short
#
# [9000 rows x 9 columns]

# %%
print(len(df_basic))
# Out:
# 9011

# %%
df_basic['startYear'] = df_basic['startYear'].replace('\\N', np.nan)
df_basic['startYear'] = df_basic['startYear'].astype('float64')
df_basic['startYear'].unique()[:5]
# Out:
# array([1898., 2018., 2016., 1987., 1973.])

# %%
df_basic['endYear'] = df_basic['endYear'].replace('\\N', np.nan)
df_basic['endYear'] = df_basic['endYear'].astype('float64')
df_basic['endYear'].unique()[:5]
# Out:
# array([  nan, 2005., 1955., 2006., 1999.])

# %%
df_basic['runtimeMinutes'] = df_basic['runtimeMinutes'].replace('\\N', np.nan)
df_basic['runtimeMinutes'] = df_basic['runtimeMinutes'].astype('string')
df_basic['runtimeMinutes'].unique()[:5]
# Out:
# <StringArray>
# [<NA>, '29', '7', '23', '85']
# Length: 5, dtype: string

# %%
def transform_to_list(x):
    if ',' in x:
        return x, split('.')
    else:
        return []
    df_basic['genres'] = df_basic['genres'].apply(lambda x:transform_to_list(x))

# %%
df_rating.head(10)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1608
# 1  tt0000002            6.0       197
# 2  tt0000003            6.5      1285
# 3  tt0000004            6.1       121
# 4  tt0000005            6.1      2050
# 5  tt0000006            5.1       111
# 6  tt0000007            5.4       639
# 7  tt0000008            5.4      1760
# 8  tt0000009            5.8       136
# 9  tt0000010            6.9      5778

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030009 entries, 0 to 1030008
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1030009 non-null  object
#  1   averageRating  1030009 non-null  float64
#  2   numVotes       1030009 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.6+ MB

# %%
df = pd.merge(df_basic, df_rating, on = 'tconst', how = 'inner')

# %%
df
# Out:
#           tconst  titleType  \
# 0      tt0043745      short
# 1      tt0167491      video
# 2      tt6574096  tvEpisode
# 3      tt6941700  tvEpisode
# 4      tt7305674      video
# ...          ...        ...
# 1373   tt0290419      movie
# 1374   tt0522596  tvEpisode
# 1375   tt7393650  tvEpisode
# 1376  tt10925142  tvEpisode
# 1377   tt3984412  tvEpisode
#
#                                            primaryTitle  \
# 0                                             Lion Down
# 1                                     Wicked Covergirls
# 2                                  Shadow Play - Part 2
# 3                                          RuPaul Roast
# 4                              UCLA Track & Field Promo
# ...                                                 ...
# 1373                                  Andru Kanda Mugam
# 1374                           The Clampetts Play Cupid
# 1375             High Hitler and His Nazi Supersoldiers
# 1376  The IMDb Show on Location: Star Wars Galaxy's ...
# 1377  I'm Not Going to Come Last, I'm Just Going to ...
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                                  Lion Down        0     1951.0      NaN
# 1                          Wicked Covergirls        1     1998.0      NaN
# 2                       Shadow Play - Part 2        0     2017.0      NaN
# 3                               RuPaul Roast        0     2017.0      NaN
# 4                   UCLA Track & Field Promo        0     2017.0      NaN
# ...                                      ...      ...        ...      ...
# 1373                       Andru Kanda Mugam        0     1968.0      NaN
# 1374                The Clampetts Play Cupid        0     1967.0      NaN
# 1375  High Hitler and His Nazi Supersoldiers        0     2016.0      NaN
# 1376                                       0     2019        NaN      NaN
# 1377                                       0     2014        NaN      NaN
#
#      runtimeMinutes                      genres  averageRating  numVotes
# 0                 7     Animation,Comedy,Family            7.1       459
# 1                85                       Adult            5.7         7
# 2                22  Adventure,Animation,Comedy            8.5       240
# 3              <NA>                  Reality-TV            8.0        11
# 4              <NA>                 Short,Sport            9.7         7
# ...             ...                         ...            ...       ...
# 1373            164                          \N            6.4         5
# 1374             30               Comedy,Family            7.5        38
# 1375           <NA>         Documentary,History            6.5         8
# 1376      Talk-Show                         NaN            7.1        15
# 1377     Reality-TV                         NaN            8.0         5
#
# [1378 rows x 11 columns]

# %%
df = df.dropna(subset = ['startYear', 'runtimeMinutes'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1004 entries, 0 to 1374
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1004 non-null   object
#  1   titleType       1004 non-null   object
#  2   primaryTitle    1004 non-null   object
#  3   originalTitle   1004 non-null   object
#  4   isAdult         1004 non-null   int64
#  5   startYear       1004 non-null   float64
#  6   endYear         17 non-null     float64
#  7   runtimeMinutes  1004 non-null   string
#  8   genres          1004 non-null   object
#  9   averageRating   1004 non-null   float64
#  10  numVotes        1004 non-null   int64
# dtypes: float64(3), int64(2), object(5), string(1)
# memory usage: 94.1+ KB

# %% [markdown]
# Task 5 - Building Simple Recommender System

# %% [markdown]
# Question 1: What is the value of C?

# %%
c =  df['averageRating'].mean()
c
# Out:
# np.float64(6.829581673306773)

# %% [markdown]
# Question 2: What is the value of m?

# %% [markdown]
# Let's take an example of a movie with numVotes above 80% of the population, so we will only take 20% of the population.

# %%
m =  df['numVotes'].quantile(0.8)
m
# Out:
# np.float64(229.0)

# %% [markdown]
# Pertanyaan 3: Bagaimana cara membuat fungsi weighted formula?

# %%
def imdb_weighted_rating(df, var=0.8):
    v = df['numVotes']
    R = df['averageRating']
    C = df['averageRating'].mean()
    m = df['numVotes'].quantile(var)
    df['score'] = (v/(m+v))*R + (m/(m+v))*C #Rumus IMDb 
    return df['score']
    
imdb_weighted_rating(df)

#melakukan pengecekan dataframe
print(df.head())
# Out:
#       tconst  titleType          primaryTitle         originalTitle  isAdult  \
# 0  tt0043745      short             Lion Down             Lion Down        0
# 1  tt0167491      video     Wicked Covergirls     Wicked Covergirls        1
# 2  tt6574096  tvEpisode  Shadow Play - Part 2  Shadow Play - Part 2        0
# 5  tt2262289      movie               The Pin               The Pin        0
# 6  tt0874027  tvEpisode         Episode #32.9         Episode #32.9        0
#
#    startYear  endYear runtimeMinutes                      genres  \
# 0     1951.0      NaN              7     Animation,Comedy,Family
# 1     1998.0      NaN             85                       Adult
# 2     2017.0      NaN             22  Adventure,Animation,Comedy
# 5     2013.0      NaN             85                       Drama
# 6     2006.0      NaN             29       Comedy,Game-Show,News
#
#    averageRating  numVotes     score
# 0            7.1       459  7.009992
# 1            5.7         7  6.796077
# 2            8.5       240  7.684380
# 5            7.7        27  6.921384
# 6            8.0         8  6.869089
# C:\Users\MyPC\AppData\Local\Temp\ipykernel_5908\2258655584.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['score'] = (v/(m+v))*R + (m/(m+v))*C #Rumus IMDb

# %% [markdown]
# Question 4: How to create a simple recommender system?

# %% [markdown]
# From the task we have done before, there is an additional field 'score'.
# First, we will filter numVotes that are more than m then sort the score from highest to lowest to take the top few scores.

# %%
def simple_recommender(df, top=100):
    df = df.loc[df['numVotes'] >= m]
    df = df.sort_values(by='score', ascending=False) #urutkan dari nilai tertinggi ke terendah
    
    #Ambil data 100 teratas
    df = df[:top]
    return df
    
#Ambil data 25 teratas     
print(simple_recommender(df, top=25))
# Out:
#          tconst  titleType                                   primaryTitle  \
# 68    tt4110822  tvEpisode                                  S.O.S. Part 2
# 236   tt2200252      video                    Attack of the Clones Review
# 1181  tt7697962  tvEpisode            Chapter Seventeen: The Missionaries
# 326   tt7124590  tvEpisode            Chapter Thirty-Four: Judgment Night
# 1045  tt0533506  tvEpisode                                       The Prom
# 71    tt8399426  tvEpisode                                        Savages
# 1234  tt2843830  tvEpisode                                          VIII.
# 1087  tt4295140   tvSeries                                   Chef's Table
# 1054  tt2503932  tvEpisode                                Trial and Error
# 448   tt0337566      video                       AC/DC: Live at Donington
# 624   tt0620159  tvEpisode                                     Strike Out
# 1281  tt3166390  tvEpisode                         Looking for a Plus-One
# 314   tt0954759  tvEpisode                                   Ben Franklin
# 189   tt5661506      video            Florence + the Machine: The Odyssey
# 151   tt3954426  tvEpisode                                Bleeding Kansas
# 1344  tt6644294  tvEpisode                 The Hostile Hospital: Part Two
# 1242  tt3677742  tvSpecial  Saturday Night Live: 40th Anniversary Special
# 1217  tt3642464  tvEpisode                                    Giant Woman
# 544   tt0734655  tvEpisode                              The Little People
# 49    tt9119838  tvEpisode                      Parisian Legend Has It...
# 357   tt4084774  tvEpisode                           Trial and Punishment
# 1111  tt4174072  tvEpisode                     Immortal Emerges from Cave
# 790   tt4279086  tvEpisode                       And Santa's Midnight Run
# 972   tt0048028      movie                                   East of Eden
# 819   tt0032156      movie            The Story of the Last Chrysanthemum
#
#                                       originalTitle  isAdult  startYear  \
# 68                                    S.O.S. Part 2        0     2015.0
# 236                     Attack of the Clones Review        0     2010.0
# 1181            Chapter Seventeen: The Missionaries        0     2019.0
# 326             Chapter Thirty-Four: Judgment Night        0     2018.0
# 1045                                       The Prom        0     1999.0
# 71                                          Savages        0     2018.0
# 1234                                          VIII.        0     2014.0
# 1087                                   Chef's Table        0     2015.0
# 1054                                Trial and Error        0     2013.0
# 448                        AC/DC: Live at Donington        0     1992.0
# 624                                      Strike Out        0     2000.0
# 1281                         Looking for a Plus-One        0     2014.0
# 314                                    Ben Franklin        0     2007.0
# 189             Florence + the Machine: The Odyssey        0     2016.0
# 151                                 Bleeding Kansas        0     2014.0
# 1344                 The Hostile Hospital: Part Two        0     2018.0
# 1242  Saturday Night Live: 40th Anniversary Special        0     2015.0
# 1217                                    Giant Woman        0     2014.0
# 544                               The Little People        0     1962.0
# 49                        Parisian Legend Has It...        0     2019.0
# 357                            Trial and Punishment        0     2015.0
# 1111                     Immortal Emerges from Cave        0     2017.0
# 790                        And Santa's Midnight Run        0     2014.0
# 972                                    East of Eden        0     1955.0
# 819                              Zangiku monogatari        0     1939.0
#
#       endYear runtimeMinutes                      genres  averageRating  \
# 68        NaN             43      Action,Adventure,Drama            9.4
# 236       NaN             86                      Comedy            9.3
# 1181      NaN             54        Drama,Fantasy,Horror            9.2
# 326       NaN             42         Crime,Drama,Mystery            9.1
# 1045      NaN             60        Action,Drama,Fantasy            8.9
# 71        NaN             58       Drama,Fantasy,Romance            9.0
# 1234      NaN             57             Adventure,Drama            8.9
# 1087      NaN             50                 Documentary            8.6
# 1054      NaN             43        Drama,Fantasy,Horror            8.6
# 448       NaN            120           Documentary,Music            8.5
# 624       NaN             30                      Comedy            8.7
# 1281      NaN             28        Comedy,Drama,Romance            8.7
# 314       NaN             21                      Comedy            8.1
# 189       NaN             49                       Music            8.8
# 151       NaN             42               Drama,Western            8.6
# 1344      NaN             40      Adventure,Comedy,Drama            8.3
# 1242      NaN            106                      Comedy            8.1
# 1217      NaN             11  Adventure,Animation,Comedy            8.4
# 544       NaN             25        Drama,Fantasy,Horror            8.1
# 49        NaN             42                       Drama            8.9
# 357       NaN             56             Adventure,Drama            8.8
# 1111      NaN             53      Action,Adventure,Crime            8.0
# 790       NaN             42     Action,Adventure,Comedy            8.2
# 972       NaN            118                       Drama            7.9
# 819       NaN            143               Drama,Romance            7.9
#
#       numVotes     score
# 68        3820  9.254624
# 236       1411  8.955045
# 1181      1536  8.892450
# 326       1859  8.850993
# 1045      2740  8.740308
# 71        1428  8.700045
# 1234      1753  8.660784
# 1087     12056  8.566998
# 1054      2495  8.451165
# 448       1343  8.256663
# 624        401  8.020118
# 1281       396  8.014679
# 314       2766  8.002863
# 189        330  7.992798
# 151        437  7.991253
# 1344       812  7.976536
# 1242      1931  7.965312
# 1217       566  7.947641
# 544       1559  7.937290
# 49         263  7.936330
# 357        289  7.928908
# 1111      2898  7.914287
# 790        823  7.901687
# 972      38543  7.893678
# 819       2974  7.823470

# %% [markdown]
# Question 5: How to create a simple recommender system with user preferences?

# %% [markdown]
# From the task that has been done before, it can be seen that now the list of movies has been sorted from the highest score to the lowest.
# Movies with a high averageRating do not always get a higher position than movies with a lower averageRating, this is because we also take into account the number of votes.
#
# This recommendation system can still be improved by adding specific filters about titleType, startYear, or other filters.
# The next work we will do is to create a function to filter by isAdult, startYear, and genres.

# %%
df_next = df.copy()

def user_prefer_recommender(df_next, ask_adult, ask_start_year, ask_genre, top=100):
    #ask_adult = yes/no
    if ask_adult.lower() == 'yes':
        df_next = df_next.loc[df['isAdult'] == 1]
    elif ask_adult.lower() == 'no':
        df_next = df_next.loc[df['isAdult'] == 0]

    #ask_start_year = numeric
    df_next = df_next.loc[df['startYear'] >= int(ask_start_year)]

    #ask_genre = 'all' atau yang lain
    if ask_genre.lower() == 'all':
        df_next = df_next
    else:
        def filter_genre(x):
            if ask_genre.lower() in str(x).lower():
                return True
            else:
                return False
        df_next = df_next.loc[df['genres'].apply(lambda x: filter_genre(x))]

    df_next = df_next.loc[df['numVotes'] >= m]  #Mengambil film dengan numVotes yang lebih besar atau sama dengan nilai m 
    df_next = df_next.sort_values(by='score', ascending=False)
    
    #jika kamu hanya ingin mengambil 100 teratas
    df_next = df_next[:top]
    return df_next

print(user_prefer_recommender(df,
                       ask_adult = 'no',
                        ask_start_year = 2000,
                       ask_genre = 'drama'
                       ))
# Out:
#          tconst  titleType                         primaryTitle  \
# 68    tt4110822  tvEpisode                        S.O.S. Part 2
# 1181  tt7697962  tvEpisode  Chapter Seventeen: The Missionaries
# 326   tt7124590  tvEpisode  Chapter Thirty-Four: Judgment Night
# 71    tt8399426  tvEpisode                              Savages
# 1234  tt2843830  tvEpisode                                VIII.
# ...         ...        ...                                  ...
# 1138  tt1126516      movie              Money Hai Toh Honey Hai
# 1208  tt3044882      movie                                Nasha
# 1197  tt3016748      movie                       Jacob's Ladder
# 846   tt0488164      movie                          Moscow Zero
# 90    tt0299981    tvMovie               Highlander: The Source
#
#                             originalTitle  isAdult  startYear  endYear  \
# 68                          S.O.S. Part 2        0     2015.0      NaN
# 1181  Chapter Seventeen: The Missionaries        0     2019.0      NaN
# 326   Chapter Thirty-Four: Judgment Night        0     2018.0      NaN
# 71                                Savages        0     2018.0      NaN
# 1234                                VIII.        0     2014.0      NaN
# ...                                   ...      ...        ...      ...
# 1138              Money Hai Toh Honey Hai        0     2008.0      NaN
# 1208                                Nasha        0     2013.0      NaN
# 1197                       Jacob's Ladder        0     2019.0      NaN
# 846                           Moscow Zero        0     2006.0      NaN
# 90                 Highlander: The Source        0     2007.0      NaN
#
#      runtimeMinutes                  genres  averageRating  numVotes     score
# 68               43  Action,Adventure,Drama            9.4      3820  9.254624
# 1181             54    Drama,Fantasy,Horror            9.2      1536  8.892450
# 326              42     Crime,Drama,Mystery            9.1      1859  8.850993
# 71               58   Drama,Fantasy,Romance            9.0      1428  8.700045
# 1234             57         Adventure,Drama            8.9      1753  8.660784
# ...             ...                     ...            ...       ...       ...
# 1138            138            Comedy,Drama            2.8       527  4.020601
# 1208            122          Drama,Thriller            3.2      1132  3.810708
# 1197             89    Drama,Horror,Mystery            3.4      2065  3.742360
# 846              82     Action,Drama,Horror            3.0      1620  3.474296
# 90               86  Action,Adventure,Drama            3.1      8855  3.194020
#
# [71 rows x 12 columns]
